# %%
import pandas as pd
import numpy as np

#Number of interns
n = 40

#Generate UNIQUE Intern IDs
ids = set()
while len(ids) < n:
    ids.add("INT" + str(np.random.randint(10000, 99999)))
ids = list(ids)

data = []

for i in range(n):
    intern_id = ids[i]

    attendance = np.random.randint(50, 100)
    consistency = np.random.randint(40, 100)
    learning = np.random.randint(40, 100)

    tasks_assigned = 20
    tasks_completed = np.random.randint(5, 21)
    completion_rate = tasks_completed / tasks_assigned

    project_score = np.random.randint(40, 100)
    evaluation_score = np.random.randint(40, 100)

    login_freq = np.random.randint(1, 7)
    active_days = np.random.randint(5, 25)

    engagement = np.random.randint(1, 10)
    communication = np.random.randint(1, 10)
    discipline = np.random.randint(1, 10)

    #Performance Logic
    if completion_rate > 0.8 and engagement > 7 and evaluation_score > 75:
        performance = 2   #High
    elif completion_rate > 0.5 and evaluation_score > 60:
        performance = 1   #Medium
    else:
        performance = 0   #Low

    data.append([
        intern_id,
        attendance,
        consistency,
        learning,
        tasks_assigned,
        tasks_completed,
        completion_rate,
        project_score,
        evaluation_score,
        login_freq,
        active_days,
        engagement,
        communication,
        discipline,
        performance
    ])

#Column names
columns = [
    "intern_id",
    "attendance_percentage",
    "consistency_score",
    "learning_score",
    "tasks_assigned",
    "tasks_completed",
    "completion_rate",
    "project_score",
    "evaluation_score",
    "login_frequency",
    "active_days",
    "engagement_score",
    "communication_score",
    "discipline_score",
    "performance_label"
]

#Create DataFrame
df = pd.DataFrame(data, columns=columns)

#Show all rows
print("Total rows:", len(df))
df
# Out:
# Total rows: 40
#    intern_id  attendance_percentage  consistency_score  learning_score  \
# 0   INT77523                     51                 47              83
# 1   INT53206                     93                 64              72
# 2   INT19398                     84                 44              99
# 3   INT74924                     74                 84              68
# 4   INT98494                     70                 85              99
# 5   INT11718                     59                 87              80
# 6   INT25511                     63                 90              42
# 7   INT89446                     60                 83              42
# 8   INT16560                     61                 76              90
# 9   INT77158                     52                 79              89
# 10  INT35895                     70                 95              42
# 11  INT56892                     72                 53              83
# ...

# %%
print("Dataset Info:")
df.info()
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   intern_id              40 non-null     object
#  1   attendance_percentage  40 non-null     int64
#  2   consistency_score      40 non-null     int64
#  3   learning_score         40 non-null     int64
#  4   tasks_assigned         40 non-null     int64
#  5   tasks_completed        40 non-null     int64
#  6   completion_rate        40 non-null     float64
#  7   project_score          40 non-null     int64
#  8   evaluation_score       40 non-null     int64
#  9   login_frequency        40 non-null     int64
#  10  active_days            40 non-null     int64
#  11  engagement_score       40 non-null     int64
#  12  communication_score    40 non-null     int64
#  13  discipline_score       40 non-null     int64
# ...

# %%
print("\nMissing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# intern_id                0
# attendance_percentage    0
# consistency_score        0
# learning_score           0
# tasks_assigned           0
# tasks_completed          0
# completion_rate          0
# project_score            0
# evaluation_score         0
# login_frequency          0
# active_days              0
# engagement_score         0
# communication_score      0
# discipline_score         0
# performance_label        0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df = df.drop("intern_id", axis=1)

# %%
print("\nAfter Cleaning:")
print(df.head())
# Out:
# After Cleaning:
#    attendance_percentage  consistency_score  learning_score  tasks_assigned  \
# 0                     51                 47              83              20
# 1                     93                 64              72              20
# 2                     84                 44              99              20
# 3                     74                 84              68              20
# 4                     70                 85              99              20
#
#    tasks_completed  completion_rate  project_score  evaluation_score  \
# 0               17             0.85             97                49
# 1               20             1.00             86                86
# 2                8             0.40             64                69
# 3                8             0.40             81                47
# 4               12             0.60             69                50
#
#    login_frequency  active_days  engagement_score  communication_score  \
# ...

# %%
# 🔹 Split features and target
X = df.drop("performance_label", axis=1)
y = df["performance_label"]

print("Features:")
print(X.head())

print("\nTarget:")
print(y.head())

# 🔹 Scaling
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Convert to DataFrame for viewing
import pandas as pd
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

print("\nScaled Data:")
print(X_scaled_df.head())
# Out:
# Features:
#    attendance_percentage  consistency_score  learning_score  tasks_assigned  \
# 0                     51                 47              83              20
# 1                     93                 64              72              20
# 2                     84                 44              99              20
# 3                     74                 84              68              20
# 4                     70                 85              99              20
#
#    tasks_completed  completion_rate  project_score  evaluation_score  \
# 0               17             0.85             97                49
# 1               20             1.00             86                86
# 2                8             0.40             64                69
# 3                8             0.40             81                47
# 4               12             0.60             69                50
#
#    login_frequency  active_days  engagement_score  communication_score  \
# ...

# %%
df.to_csv("intern_dataset.csv", index=False)
